# %%
import pandas as pd

# %%
measure = pd.read_csv('hawaii_measurements.csv')
measure
# Out:
#            STATION     DATE  PRCP  TOBS
# 0      USC00519397   1/1/10  0.08    65
# 1      USC00519397   1/2/10  0.00    63
# 2      USC00519397   1/3/10  0.00    74
# 3      USC00519397   1/4/10  0.00    76
# 4      USC00519397   1/6/10   NaN    73
# 5      USC00519397   1/7/10  0.06    70
# 6      USC00519397   1/8/10  0.00    64
# 7      USC00519397   1/9/10  0.00    68
# 8      USC00519397  1/10/10  0.00    73
# 9      USC00519397  1/11/10  0.01    64
# 10     USC00519397  1/12/10  0.00    61
# 11     USC00519397  1/14/10  0.00    66
# 12     USC00519397  1/15/10  0.00    65
# 13     USC00519397  1/16/10  0.00    68
# 14     USC00519397  1/17/10  0.00    64
# 15     USC00519397  1/18/10  0.00    72
# 16     USC00519397  1/19/10  0.00    66
# 17     USC00519397  1/20/10  0.00    66
# 18     USC00519397  1/21/10  0.00    69
# 19     USC00519397  1/22/10  0.00    67
# 20     USC00519397  1/23/10  0.00    67
# 21     USC00519397  1/24/10  0.01    71
# ...

# %%
stations = pd.read_csv('hawaii_stations.csv')
stations
# Out:
#        STATION                                    NAME  LATITUDE  LONGITUDE  \
# 0  USC00519397                    WAIKIKI 717.2, HI US  21.27160 -157.81680
# 1  USC00513117                    KANEOHE 838.1, HI US  21.42340 -157.80150
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740
# 3  USC00517948                       PEARL CITY, HI US  21.39340 -157.97510
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920 -158.01110
# 5  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# 6  USC00519281                     WAIHEE 837.5, HI US  21.45167 -157.84889
# 7  USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# 8  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
#
#    ELEVATION
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6
# 5       19.5
# 6       32.9
# 7        0.9
# 8      152.4

# %%
measure = measure.dropna(how='any')
measure
# Out:
#            STATION     DATE  PRCP  TOBS
# 0      USC00519397   1/1/10  0.08    65
# 1      USC00519397   1/2/10  0.00    63
# 2      USC00519397   1/3/10  0.00    74
# 3      USC00519397   1/4/10  0.00    76
# 5      USC00519397   1/7/10  0.06    70
# 6      USC00519397   1/8/10  0.00    64
# 7      USC00519397   1/9/10  0.00    68
# 8      USC00519397  1/10/10  0.00    73
# 9      USC00519397  1/11/10  0.01    64
# 10     USC00519397  1/12/10  0.00    61
# 11     USC00519397  1/14/10  0.00    66
# 12     USC00519397  1/15/10  0.00    65
# 13     USC00519397  1/16/10  0.00    68
# 14     USC00519397  1/17/10  0.00    64
# 15     USC00519397  1/18/10  0.00    72
# 16     USC00519397  1/19/10  0.00    66
# 17     USC00519397  1/20/10  0.00    66
# 18     USC00519397  1/21/10  0.00    69
# 19     USC00519397  1/22/10  0.00    67
# 20     USC00519397  1/23/10  0.00    67
# 21     USC00519397  1/24/10  0.01    71
# 22     USC00519397  1/25/10  0.00    67
# ...

# %%
stations = stations.dropna(how='any')
stations
# Out:
#        STATION                                    NAME  LATITUDE  LONGITUDE  \
# 0  USC00519397                    WAIKIKI 717.2, HI US  21.27160 -157.81680
# 1  USC00513117                    KANEOHE 838.1, HI US  21.42340 -157.80150
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130 -157.83740
# 3  USC00517948                       PEARL CITY, HI US  21.39340 -157.97510
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920 -158.01110
# 5  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556 -157.71139
# 6  USC00519281                     WAIHEE 837.5, HI US  21.45167 -157.84889
# 7  USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520 -157.99920
# 8  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310 -157.80250
#
#    ELEVATION
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6
# 5       19.5
# 6       32.9
# 7        0.9
# 8      152.4

# %%
measure.to_csv("clean_hawaii_measurements.csv", encoding="utf-8",  index=False)
stations.to_csv("clean_hawaii_statioins.csv", encoding="utf-8", index=False)
