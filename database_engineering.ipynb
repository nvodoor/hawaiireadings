# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, DateTime, VARCHAR, Interval
from sqlalchemy.orm import Session

# %%
#Creating Dataframes from Cleaned CSVs
cleanmeasure = pd.read_csv('clean_hawaii_measurements.csv')
cleanstation = pd.read_csv('clean_hawaii_statioins.csv')

# %%
#Check if worked
cleanmeasure.head()
# Out:
#        STATION    DATE  PRCP  TOBS
# 0  USC00519397  1/1/10  0.08    65
# 1  USC00519397  1/2/10  0.00    63
# 2  USC00519397  1/3/10  0.00    74
# 3  USC00519397  1/4/10  0.00    76
# 4  USC00519397  1/7/10  0.06    70

# %%
#create isodate in pandas
cleanmeasure['ISODATE'] = pd.to_datetime(cleanmeasure['DATE'], format='%m/%d/%y')
cleanmeasure.head()
# Out:
#        STATION    DATE  PRCP  TOBS    ISODATE
# 0  USC00519397  1/1/10  0.08    65 2010-01-01
# 1  USC00519397  1/2/10  0.00    63 2010-01-02
# 2  USC00519397  1/3/10  0.00    74 2010-01-03
# 3  USC00519397  1/4/10  0.00    76 2010-01-04
# 4  USC00519397  1/7/10  0.06    70 2010-01-07

# %%
#Check if worked
cleanstation.head()
# Out:
#        STATION                                    NAME  LATITUDE  LONGITUDE  \
# 0  USC00519397                    WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1  USC00513117                    KANEOHE 838.1, HI US   21.4234  -157.8015
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213  -157.8374
# 3  USC00517948                       PEARL CITY, HI US   21.3934  -157.9751
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US   21.4992  -158.0111
#
#    ELEVATION
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6

# %%
#Creating a database called Hawaii.
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
#Connecting to Database
conn = engine.connect()

# %%
#Declaring a base
Base = declarative_base()

# %%
#Creating Measurement Table
#DateTime is only way the IsoDate would be parsed.
class Measurement(Base):
    __tablename__ = 'Measurement'
    
    id = Column(Integer, primary_key = True)
    STATION = Column(VARCHAR)
    DATE = Column(Text)
    PRCP = Column(Integer)
    TOBS = Column(Integer)
    ISODATE = Column(DateTime)
    
    def __repr__(self):
        return f"id={self.id}, Date={self.Date}"

# %%
#Creating Station Table
class Station(Base):
    
    __tablename__ = 'Station'
    
    id = Column(Integer, primary_key = True)
    STATION = Column(VARCHAR)
    NAME = Column(VARCHAR)
    LATITUDE = Column(Float)
    LONGITUDE = Column(Float)
    ELEVATION = Column(Float)
    
    def __repr__(self):
        return f"id={self.id}, Name={self.Name}"

# %%
#Create Station and Measurement Table in Database
Base.metadata.create_all(engine)

# %%
#Creating JSONIFIED data out of Measurement Data
data = cleanmeasure.to_dict(orient='records')

# %%
#Check if above worked
print(data)
# Out:
# [{'STATION': 'USC00519397', 'DATE': '1/1/10', 'PRCP': 0.08, 'TOBS': 65, 'ISODATE': Timestamp('2010-01-01 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/2/10', 'PRCP': 0.0, 'TOBS': 63, 'ISODATE': Timestamp('2010-01-02 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/3/10', 'PRCP': 0.0, 'TOBS': 74, 'ISODATE': Timestamp('2010-01-03 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/4/10', 'PRCP': 0.0, 'TOBS': 76, 'ISODATE': Timestamp('2010-01-04 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/7/10', 'PRCP': 0.06, 'TOBS': 70, 'ISODATE': Timestamp('2010-01-07 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/8/10', 'PRCP': 0.0, 'TOBS': 64, 'ISODATE': Timestamp('2010-01-08 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/9/10', 'PRCP': 0.0, 'TOBS': 68, 'ISODATE': Timestamp('2010-01-09 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/10/10', 'PRCP': 0.0, 'TOBS': 73, 'ISODATE': Timestamp('2010-01-10 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/11/10', 'PRCP': 0.01, 'TOBS': 64, 'ISODATE': Timestamp('2010-01-11 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/12/10', 'PRCP': 0.0, 'TOBS': 61, 'ISODATE': Timestamp('2010-01-12 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/14/10', 'PRCP': 0.0, 'TOBS': 66, 'ISODATE': Timestamp('2010-01-14 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/15/10', 'PRCP': 0.0, 'TOBS': 65, 'ISODATE': Timestamp('2010-01-15 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/16/10', 'PRCP': 0.0, 'TOBS': 68, 'ISODATE': Timestamp('2010-01-16 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/17/10', 'PRCP': 0.0, 'TOBS': 64, 'ISODATE': Timestamp('2010-01-17 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/18/10', 'PRCP': 0.0, 'TOBS': 72, 'ISODATE': Timestamp('2010-01-18 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/19/10', 'PRCP': 0.0, 'TOBS': 66, 'ISODATE': Timestamp('2010-01-19 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/20/10', 'PRCP': 0.0, 'TOBS': 66, 'ISODATE': Timestamp('2010-01-20 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/21/10', 'PRCP': 0.0, 'TOBS': 69, 'ISODATE': Timestamp('2010-01-21 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/22/10', 'PRCP': 0.0, 'TOBS': 67, 'ISODATE': Timestamp('2010-01-22 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/23/10', 'PRCP': 0.0, 'TOBS': 67, 'ISODATE': Timestamp('2010-01-23 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/24/10', 'PRCP': 0.01, 'TOBS': 71, 'ISODATE': Timestamp('2010-01-24 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/25/10', 'PRCP': 0.0, 'TOBS': 67, 'ISODATE': Timestamp('2010-01-25 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/26/10', 'PRCP': 0.04, 'TOBS': 76, 'ISODATE': Timestamp('2010-01-26 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/27/10', 'PRCP': 0.12, 'TOBS': 68, 'ISODATE': Timestamp('2010-01-27 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/28/10', 'PRCP': 0.0, 'TOBS': 72, 'ISODATE': Timestamp('2010-01-28 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '1/31/10', 'PRCP': 0.03, 'TOBS': 67, 'ISODATE': Timestamp('2010-01-31 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/1/10', 'PRCP': 0.01, 'TOBS': 66, 'ISODATE': Timestamp('2010-02-01 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/4/10', 'PRCP': 0.01, 'TOBS': 69, 'ISODATE': Timestamp('2010-02-04 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/5/10', 'PRCP': 0.0, 'TOBS': 67, 'ISODATE': Timestamp('2010-02-05 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/6/10', 'PRCP': 0.0, 'TOBS': 67, 'ISODATE': Timestamp('2010-02-06 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/7/10', 'PRCP': 0.0, 'TOBS': 64, 'ISODATE': Timestamp('2010-02-07 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/8/10', 'PRCP': 0.0, 'TOBS': 69, 'ISODATE': Timestamp('2010-02-08 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/9/10', 'PRCP': 0.0, 'TOBS': 73, 'ISODATE': Timestamp('2010-02-09 00:00:00')}, {'STATION': 'USC00519397', 'DATE': '2/11/10', 'PRCP': 0.0, 'TOBS': 73, 'ISODATE': Timestamp('2010-02-11 00:00:00')}, {'STATION': 'USC00519397', ...

# %%
# Use MetaData from SQLAlchemy to reflect the tables
metadata = MetaData(bind=engine)
metadata.reflect()

# %%
# Save the reference to the `Measurement` table as a variable called `table`
table = sqlalchemy.Table('Measurement', metadata, autoload=True)

# %%
#Remove pre-existing data
conn.execute(table.delete())

# %%
#Insert Data into table
conn.execute(table.insert(), data)

# %%
#Test to see if it worked
conn.execute("select * from Measurement limit 10").fetchall()
#Note if Schema is screwed up - delete the sqlite file and start over again.
# Out:
# [(1, 'USC00519397', '1/1/10', 0.08, 65, '2010-01-01 00:00:00.000000'),
#  (2, 'USC00519397', '1/2/10', 0, 63, '2010-01-02 00:00:00.000000'),
#  (3, 'USC00519397', '1/3/10', 0, 74, '2010-01-03 00:00:00.000000'),
#  (4, 'USC00519397', '1/4/10', 0, 76, '2010-01-04 00:00:00.000000'),
#  (5, 'USC00519397', '1/7/10', 0.06, 70, '2010-01-07 00:00:00.000000'),
#  (6, 'USC00519397', '1/8/10', 0, 64, '2010-01-08 00:00:00.000000'),
#  (7, 'USC00519397', '1/9/10', 0, 68, '2010-01-09 00:00:00.000000'),
#  (8, 'USC00519397', '1/10/10', 0, 73, '2010-01-10 00:00:00.000000'),
#  (9, 'USC00519397', '1/11/10', 0.01, 64, '2010-01-11 00:00:00.000000'),
#  (10, 'USC00519397', '1/12/10', 0, 61, '2010-01-12 00:00:00.000000')]

# %%
#Creating JSONIFIED data out of Station Data
data = cleanstation.to_dict(orient='records')

# %%
#Check if above worked
print(data)
# Out:
# [{'STATION': 'USC00519397', 'NAME': 'WAIKIKI 717.2, HI US', 'LATITUDE': 21.2716, 'LONGITUDE': -157.8168, 'ELEVATION': 3.0}, {'STATION': 'USC00513117', 'NAME': 'KANEOHE 838.1, HI US', 'LATITUDE': 21.4234, 'LONGITUDE': -157.8015, 'ELEVATION': 14.6}, {'STATION': 'USC00514830', 'NAME': 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 'LATITUDE': 21.5213, 'LONGITUDE': -157.8374, 'ELEVATION': 7.0}, {'STATION': 'USC00517948', 'NAME': 'PEARL CITY, HI US', 'LATITUDE': 21.3934, 'LONGITUDE': -157.9751, 'ELEVATION': 11.9}, {'STATION': 'USC00518838', 'NAME': 'UPPER WAHIAWA 874.3, HI US', 'LATITUDE': 21.4992, 'LONGITUDE': -158.0111, 'ELEVATION': 306.6}, {'STATION': 'USC00519523', 'NAME': 'WAIMANALO EXPERIMENTAL FARM, HI US', 'LATITUDE': 21.33556, 'LONGITUDE': -157.71139, 'ELEVATION': 19.5}, {'STATION': 'USC00519281', 'NAME': 'WAIHEE 837.5, HI US', 'LATITUDE': 21.45167, 'LONGITUDE': -157.84888999999995, 'ELEVATION': 32.9}, {'STATION': 'USC00511918', 'NAME': 'HONOLULU OBSERVATORY 702.2, HI US', 'LATITUDE': 21.3152, 'LONGITUDE': -157.9992, 'ELEVATION': 0.9}, {'STATION': 'USC00516128', 'NAME': 'MANOA LYON ARBO 785.2, HI US', 'LATITUDE': 21.3331, 'LONGITUDE': -157.8025, 'ELEVATION': 152.4}]

# %%
# Save the reference to the `Station` table as a variable called `table`
table = sqlalchemy.Table('Station', metadata, autoload=True)

# %%
#Remove pre-existing data
conn.execute(table.delete())

# %%
# session = Session(bind=engine)

# %%
conn.execute(table.insert(), data)

# %%
conn.execute("select * from Station limit 10").fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999995, 32.9),
#  (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %%
#Note for above data column names and class Table names must exactly match. Otherwise the data won't be entered in.
